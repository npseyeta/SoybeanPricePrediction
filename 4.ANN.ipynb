# %%
#Connect with Drive
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import os
import datetime

import pandas as pd 
import numpy as np
import random

from sklearn.preprocessing import LabelEncoder, StandardScaler, MinMaxScaler

import tensorflow as tf
seed_value= 0
os.environ['PYTHONHASHSEED']=str(seed_value)
random.seed(seed_value)
np.random.seed(seed_value)
tf.random.set_seed(seed_value)
session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
tf.compat.v1.keras.backend.set_session(sess)
from tensorflow import keras
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Flatten, Dense,BatchNormalization,Conv1D,MaxPooling1D,Dropout

from sklearn.metrics import classification_report ,confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

# %%
def get_data_from_years(dataframe, wanted_years):
  assert type(wanted_years) is list
  assert len(wanted_years) > 0

  idx = []
  for index, row in dataframe.iterrows():
    if int(str(row['dates'])[:4]) in wanted_years:
      idx.append(index)

  return pd.DataFrame(dataframe.iloc[idx]).reset_index(drop=True)

def group_date(date):
  date = date.strip()
  d, m, y = date.split('/')
  year, week, weekday = datetime.date(int(y), int(m), int(d)).isocalendar()
  return str(year) + str(week).zfill(2)

# %%
def stat_model_predict(clf, x, y):
 
  predictions = clf.predict(x)
  predictions = np.where(predictions > 0.5, 1, 0)
  y_hat = pd.DataFrame(predictions)

  print(classification_report(y, predictions, digits=4))

  cm = confusion_matrix(y, predictions)
  disp = ConfusionMatrixDisplay(confusion_matrix=cm)
  disp.plot()
  plt.show()

  return y_hat

data = data.reset_index(drop=True)

all_years = [2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022]
split_index = 6

model_train = get_data_from_years(data, all_years[:split_index])
model_test = get_data_from_years(data, all_years[6:])

# %%
data = pd.read_csv('/content/gdrive/My Drive/Colab Notebooks/soybean_dataset.csv')
data
# Out:
#                                       week   dates  price_next_week  \
# 0             วันที่ 9 -13 กุมภาพันธ์ 2558  201507                1
# 1            วันที่ 16-20 กุมภาพันธ์ 2558   201508                1
# 2             วันที่ 23 - 27กุมภาพันธ์2558  201509                0
# 3                วันที่ 2 - 6 มีนาคม 2558   201510                0
# 4                 วันที่ 9-13 มีนาคม 2558   201511                0
# ..                                     ...     ...              ...
# 353                 วันที่ 3-7 มกราคม 2565  202201                0
# 354               วันที่ 10-14 มกราคม 2565  202202                1
# 355               วันที่ 17-21 มกราคม 2565  202203                1
# 356               วันที่ 24-28 มกราคม 2565  202204                1
# 357   วันที่ 31 มกราคม - 4 กุมภาพันธ์ 2565  202205                1
#
#      sum_c_vec  sum_tf_vec  news_price       MACD  MACD_SIGNAL  MACD_DIFF  \
# 0          115    6.063669          -1 -10.640456   -12.772359   2.131903
# 1          107    5.812786           0  -3.022899    -8.237728   5.214829
# 2          109    5.753888           0   2.948086    -2.374953   5.323039
# 3           92    5.227960           0   4.384361     2.591326   1.793035
# 4          100    5.703614           0  -1.004628     1.145109  -2.149738
# ..         ...         ...         ...        ...          ...        ...
# 353        196    8.822123           1  30.709619    24.604390   6.105229
# 354        240    8.600711           1  32.286825    30.261029   2.025796
# 355        191    8.671932           0  26.811105    28.807734  -1.996629
# 356        189    8.306811           0  29.307491    28.483037   0.824454
# 357        222    8.579548           1  45.743451    36.057292   9.686159
#
#          TAS_K  ...  Crushing_Million Bushels  Ending Stocks_Million Bushels  \
# 0    40.442610  ...                    1795.0                          385.0
# 1    81.127346  ...                    1795.0                          385.0
# 2    82.485961  ...                    1795.0                          385.0
# 3    45.347177  ...                    1795.0                          385.0
# 4    25.504981  ...                    1795.0                          385.0
# ..         ...  ...                       ...                            ...
# 353  94.230787  ...                    2190.0                          340.0
# 354  80.174787  ...                    2190.0                          350.0
# 355  81.269727  ...                    2190.0                          350.0
# 356  87.770796  ...                    2190.0                          350.0
# 357  93.508507  ...                    2190.0                          350.0
#
#      Exports_Million Bushels  Imports_Million Bushels  \
# 0                     1790.0                     25.0
# 1                     1790.0                     25.0
# 2                     1790.0                     25.0
# 3                     1790.0                     25.0
# 4                     1790.0                     25.0
# ..                       ...                      ...
# 353                   2050.0                     15.0
# 354                   2050.0                     15.0
# 355                   2050.0                     15.0
# 356                   2050.0                     15.0
# 357                   2050.0                     15.0
#
#      Production_Million Bushels  Residual Use_Million Bushels  \
# 0                        3969.0                          24.0
# 1                        3969.0                          24.0
# 2                        3969.0                          24.0
# 3                        3969.0                          24.0
# 4                        3969.0                          24.0
# ..                          ...                           ...
# 353                      4425.0                          15.0
# 354                      4435.0                          16.0
# 355                      4435.0                          16.0
# 356                      4435.0                          16.0
# 357                      4435.0                          16.0
#
#      Seed Use_Million Bushels  Total demand_Million Bushels  \
# 0                        92.0                        3701.0
# 1                        92.0                        3701.0
# 2                        92.0                        3701.0
# 3                        92.0                        3701.0
# 4                        92.0                        3701.0
# ..                        ...                           ...
# 353                     102.0                        4356.0
# 354                     102.0                        4357.0
# 355                     102.0                        4357.0
# 356                     102.0                        4357.0
# 357                     102.0                        4357.0
#
#      Total Supply_Million Bushels  Yield_Bushels/Acre
# 0                          4086.0                47.8
# 1                          4086.0                47.8
# 2                          4086.0                47.8
# 3                          4086.0                47.8
# 4                          4086.0                47.8
# ..                            ...                 ...
# 353                        4696.0                51.2
# 354                        4707.0                51.4
# 355                        4707.0                51.4
# 356                        4707.0                51.4
# 357                        4707.0                51.4
#
# [358 rows x 34 columns]

# %%
x_columns = ['sum_c_vec', 'sum_tf_vec','news_price', 'MACD', 'MACD_SIGNAL', 
             'MACD_DIFF', 'TAS_K', 'TAS_D', 'TAS_DS', 'TAS_DSS', 'CMCI',
             'RSI', 'BB_MA', 'BB_UPPER', 'BB_LOWER', 'BB_WIDTH', 'BB_PERCENT',
             'Area Harvested_Million Acres', 'Area Planted_Million Acres',
             'Average Farm Price_US Dollars/Bushel', 'Begining Stocks_Million Bushels',
             'Crushing_Million Bushels', 'Ending Stocks_Million Bushels',
             'Exports_Million Bushels', 'Imports_Million Bushels', 'Production_Million Bushels',
             'Residual Use_Million Bushels', 'Seed Use_Million Bushels', 'Total demand_Million Bushels',
             'Total Supply_Million Bushels', 'Yield_Bushels/Acre']

y_train = model_train['price_next_week']
x_train = model_train[x_columns]

y_test = model_test['price_next_week']
x_test = model_test[x_columns]

y_hat = pd.DataFrame()

scaler = StandardScaler()
x_train = scaler.fit_transform(x_train).astype(np.float32)
x_test = scaler.fit_transform(x_test).astype(np.float32)

label = LabelEncoder()
y_train = label.fit_transform(y_train).astype(float)
y_test = label.fit_transform(y_test).astype(float)

# %%
model = Sequential()
model.add(Dense(x_train.shape[1], activation='relu', input_dim=x_train.shape[1]))
model.add(Dense(128))
model.add(Dense(64))
model.add(Dense(32))
model.add(Dense(16, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
keras.utils.plot_model(model, "model_cnnlstm.png", show_shapes=True)

# %%
model.compile(loss='binary_crossentropy', metrics=['accuracy'], run_eagerly=True)

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
data_dir = os.getcwd() + '/gdrive/My Drive/Model'
filepath= data_dir +"/weights.hdf5"
callbacks = [ModelCheckpoint(filepath, monitor='loss', save_best_only=True)]

# %%
history = model.fit(x_train, y_train, batch_size=300, epochs=300, verbose=1, shuffle=False, callbacks=callbacks)
# learning curves of model accuracy
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['loss'], label='loss')
plt.legend()
plt.show()
# Out:
# Epoch 1/300
# 2/2 [==============================] - 0s 82ms/step - loss: 0.7157 - accuracy: 0.5033
# Epoch 2/300
# 2/2 [==============================] - 0s 33ms/step - loss: 0.7199 - accuracy: 0.5364
# Epoch 3/300
# 2/2 [==============================] - 0s 82ms/step - loss: 0.7006 - accuracy: 0.5331
# Epoch 4/300
# 2/2 [==============================] - 0s 78ms/step - loss: 0.6916 - accuracy: 0.5629
# Epoch 5/300
# 2/2 [==============================] - 0s 91ms/step - loss: 0.6859 - accuracy: 0.5795
# Epoch 6/300
# 2/2 [==============================] - 0s 80ms/step - loss: 0.6792 - accuracy: 0.5927
# Epoch 7/300
# 2/2 [==============================] - 0s 82ms/step - loss: 0.6700 - accuracy: 0.6060
# Epoch 8/300
# 2/2 [==============================] - 0s 81ms/step - loss: 0.6625 - accuracy: 0.6291
# Epoch 9/300
# 2/2 [==============================] - 0s 79ms/step - loss: 0.6548 - accuracy: 0.6391
# Epoch 10/300
# 2/2 [==============================] - 0s 86ms/step - loss: 0.6487 - accuracy: 0.6391
# Epoch 11/300
# 2/2 [==============================] - 0s 111ms/step - loss: 0.6435 - accuracy: 0.6656
# Epoch 12/300
# 2/2 [==============================] - 0s 82ms/step - loss: 0.6410 - accuracy: 0.6391
# Epoch 13/300
# 2/2 [==============================] - 0s 32ms/step - loss: 0.6439 - accuracy: 0.6623
# Epoch 14/300
# 2/2 [==============================] - 0s 33ms/step - loss: 0.6459 - accuracy: 0.6325
# Epoch 15/300
# 2/2 [==============================] - 0s 80ms/step - loss: 0.6341 - accuracy: 0.6490
# Epoch 16/300
# 2/2 [==============================] - 0s 81ms/step - loss: 0.6277 - accuracy: 0.6523
# Epoch 17/300
# 2/2 [==============================] - 0s 80ms/step - loss: 0.6196 - accuracy: 0.6854
# Epoch 18/300
# 2/2 [==============================] - 0s 116ms/step - loss: 0.6140 - accuracy: 0.6689
# Epoch 19/300
# 2/2 [==============================] - 0s 85ms/step - loss: 0.6122 - accuracy: 0.6755
# Epoch 20/300
# 2/2 [==============================] - 0s 35ms/step - loss: 0.6144 - accuracy: 0.6623
# Epoch 21/300
# 2/2 [==============================] - 0s 37ms/step - loss: 0.6134 - accuracy: 0.6523
# Epoch 22/300
# 2/2 [==============================] - 0s 83ms/step - loss: 0.6087 - accuracy: 0.6556
# Epoch 23/300
# 2/2 [==============================] - 0s 85ms/step - loss: 0.6016 - accuracy: 0.6656
# Epoch 24/300
# 2/2 [==============================] - 0s 86ms/step - loss: 0.5920 - accuracy: 0.6689
# Epoch 25/300
# 2/2 [==============================] - 0s 94ms/step - loss: 0.5863 - accuracy: 0.6921
# Epoch 26/300
# 2/2 [==============================] - 0s 76ms/step - loss: 0.5845 - accuracy: 0.6689
# Epoch 27/300
# 2/2 [==============================] - 0s 81ms/step - loss: 0.5837 - accuracy: 0.6921
# Epoch 28/300
# 2/2 [==============================] - 0s 81ms/step - loss: 0.5818 - accuracy: 0.6623
# Epoch 29/300
# 2/2 [==============================] - 0s 75ms/step - loss: 0.5788 - accuracy: 0.6887
# Epoch 30/300
# 2/2 [==============================] - 0s 75ms/step - loss: 0.5723 - accuracy: 0.6921
# Epoch 31/300
# 2/2 [==============================] - 0s 86ms/step - loss: 0.5676 - accuracy: 0.7086
# Epoch 32/300
# 2/2 [==============================] - 0s 89ms/step - loss: 0.5638 - accuracy: 0.6887
# Epoch 33/300
# 2/2 [==============================] - 0s 75ms/step - loss: 0.5596 - accuracy: 0.7119
# Epoch 34/300
# 2/2 [==============================] - 0s 79ms/step - loss: 0.5576 - accuracy: 0.6854
# Epoch 35/300
# 2/2 [==============================] - 0s 76ms/step - loss: 0.5537 - accuracy: 0.7119
# Epoch 36/300
# 2/2 [==============================] - 0s 77ms/step - loss: 0.5522 - accuracy: 0.6887
# Epoch 37/300
# 2/2 [==============================] - 0s 91ms/step - loss: 0.5503 - accuracy: 0.7119
# Epoch 38/300
# 2/2 [==============================] - 0s 83ms/step - loss: 0.5452 - accuracy: 0.7053
# Epoch 39/300
# 2/2 [==============================] - 0s 91ms/step - loss: 0.5359 - accuracy: 0.7285
# Epoch 40/300
# 2/2 [==============================] - 0s 95ms/step - loss: 0.5294 - accuracy: 0.7086
# Epoch 41/300
# 2/2 [==============================] - 0s 89ms/step - loss: 0.5255 - accuracy: 0.7384
# Epoch 42/300
# 2/2 [==============================] - 0s 39ms/step - loss: 0.5267 - accuracy: 0.7119
# Epoch 43/300
# 2/2 [==============================] - 0s 34ms/step - loss: 0.5288 - accuracy: 0.7417
# Epoch 44/300
# 2/2 [==============================] - 0s 40ms/step - loss: 0.5305 - accuracy: 0.7185
# Epoch 45/300
# 2/2 [==============================] - 0s 88ms/step - loss: 0.5251 - accuracy: 0.7450
# Epoch 46/300
# 2/2 [==============================] - 0s 88ms/step - loss: 0.5124 - accuracy: 0.7185
# Epoch 47/300
# 2/2 [==============================] - 0s 92ms/step - loss: 0.5039 - accuracy: 0.7649
# Epoch 48/300
# 2/2 [==============================] - 0s 89ms/step - loss: 0.4969 - accuracy: 0.7351
# Epoch 49/300
# 2/2 [==============================] - 0s 72ms/step - loss: 0.4946 - accuracy: 0.7748
# Epoch 50/300
# 2/2 [==============================] - 0s 34ms/step - loss: 0.5010 - accuracy: 0.7285
# Epoch 51/300
# 2/2 [==============================] - 0s 32ms/step - loss: 0.5040 - accuracy: 0.7517
# Epoch 52/300
# 2/2 [==============================] - 0s 31ms/step - loss: 0.5000 - accuracy: 0.7318
# Epoch 53/300
# 2/2 [==============================] - 0s 33ms/step - loss: 0.4962 - accuracy: 0.7616
# Epoch 54/300
# 2/2 [==============================] - 0s 98ms/step - loss: 0.4860 - accuracy: 0.7483
# Epoch 55/300
# 2/2 [==============================] - 0s 87ms/step - loss: 0.4783 - accuracy: 0.7748
# Epoch 56/300
# 2/2 [==============================] - 0s 77ms/step - loss: 0.4730 - accuracy: 0.7649
# Epoch 57/300
# 2/2 [==============================] - 0s 98ms/step - loss: 0.4722 - accuracy: 0.7815
# Epoch 58/300
# 2/2 [==============================] - 0s 89ms/step - loss: 0.4709 - accuracy: 0.7517
# Epoch 59/300
# 2/2 [==============================] - 0s 34ms/step - loss: 0.4775 - accuracy: 0.7781
# Epoch 60/300
# 2/2 [==============================] - 0s 38ms/step - loss: 0.4724 - accuracy: 0.7550
# Epoch 61/300
# 2/2 [==============================] - 0s 78ms/step - loss: 0.4691 - accuracy: 0.7980
# Epoch 62/300
# 2/2 [==============================] - 0s 87ms/step - loss: 0.4571 - accuracy: 0.7781
# Epoch 63/300
# 2/2 [==============================] - 0s 73ms/step - loss: 0.4533 - accuracy: 0.7980
# Epoch 64/300
# 2/2 [==============================] - 0s 43ms/step - loss: 0.4572 - accuracy: 0.7781
# Epoch 65/300
# 2/2 [==============================] - 0s 43ms/step - loss: 0.4648 - accuracy: 0.7815
# Epoch 66/300
# 2/2 [==============================] - 0s 36ms/step - loss: 0.4563 - accuracy: 0.7781
# Epoch 67/300
# 2/2 [==============================] - 0s 86ms/step - loss: 0.4456 - accuracy: 0.7980
# Epoch 68/300
# 2/2 [==============================] - 0s 79ms/step - loss: 0.4416 - accuracy: 0.7748
# Epoch 69/300
# 2/2 [==============================] - 0s 93ms/step - loss: 0.4404 - accuracy: 0.8046
# Epoch 70/300
# 2/2 [==============================] - 0s 94ms/step - loss: 0.4323 - accuracy: 0.8146
# Epoch 71/300
# 2/2 [==============================] - 0s 110ms/step - loss: 0.4317 - accuracy: 0.8146
# Epoch 72/300
# 2/2 [==============================] - 0s 79ms/step - loss: 0.4310 - accuracy: 0.8046
# Epoch 73/300
# 2/2 [==============================] - 0s 39ms/step - loss: 0.4401 - accuracy: 0.8046
# Epoch 74/300
# 2/2 [==============================] - 0s 36ms/step - loss: 0.4337 - accuracy: 0.7914
# Epoch 75/300
# 2/2 [==============================] - 0s 85ms/step - loss: 0.4269 - accuracy: 0.8113
# Epoch 76/300
# 2/2 [==============================] - 0s 74ms/step - loss: 0.4174 - accuracy: 0.7980
# Epoch 77/300
# 2/2 [==============================] - 0s 31ms/step - loss: 0.4177 - accuracy: 0.8146
# Epoch 78/300
# 2/2 [==============================] - 0s 85ms/step - loss: 0.4153 - accuracy: 0.8113
# Epoch 79/300
# 2/2 [==============================] - 0s 35ms/step - loss: 0.4155 - accuracy: 0.8146
# Epoch 80/300
# 2/2 [==============================] - 0s 74ms/step - loss: 0.4153 - accuracy: 0.8146
# Epoch 81/300
# 2/2 [==============================] - 0s 82ms/step - loss: 0.4126 - accuracy: 0.8245
# Epoch 82/300
# 2/2 [==============================] - 0s 81ms/step - loss: 0.3994 - accuracy: 0.8411
# Epoch 83/300
# 2/2 [==============================] - 0s 39ms/step - loss: 0.4005 - accuracy: 0.8311
# Epoch 84/300
# 2/2 [==============================] - 0s 36ms/step - loss: 0.4005 - accuracy: 0.8278
# Epoch 85/300
# 2/2 [==============================] - 0s 37ms/step - loss: 0.4067 - accuracy: 0.8113
# Epoch 86/300
# 2/2 [==============================] - 0s 37ms/step - loss: 0.4004 - accuracy: 0.8079
# Epoch 87/300
# 2/2 [==============================] - 0s 91ms/step - loss: 0.3947 - accuracy: 0.8212
# Epoch 88/300
# 2/2 [==============================] - 0s 84ms/step - loss: 0.3886 - accuracy: 0.8344
# Epoch 89/300
# 2/2 [==============================] - 0s 83ms/step - loss: 0.3864 - accuracy: 0.8212
# Epoch 90/300
# 2/2 [==============================] - 0s 87ms/step - loss: 0.3843 - accuracy: 0.8278
# Epoch 91/300
# 2/2 [==============================] - 0s 97ms/step - loss: 0.3814 - accuracy: 0.8377
# Epoch 92/300
# 2/2 [==============================] - 0s 82ms/step - loss: 0.3673 - accuracy: 0.8609
# Epoch 93/300
# 2/2 [==============================] - 0s 82ms/step - loss: 0.3668 - accuracy: 0.8377
# Epoch 94/300
# 2/2 [==============================] - 0s 40ms/step - loss: 0.3745 - accuracy: 0.8444
# Epoch 95/300
# 2/2 [==============================] - 0s 33ms/step - loss: 0.3929 - accuracy: 0.8311
# Epoch 96/300
# 2/2 [==============================] - 0s 34ms/step - loss: 0.3924 - accuracy: 0.8245
# Epoch 97/300
# 2/2 [==============================] - 0s 33ms/step - loss: 0.3778 - accuracy: 0.8179
# Epoch 98/300
# 2/2 [==============================] - 0s 86ms/step - loss: 0.3643 - accuracy: 0.8278
# Epoch 99/300
# 2/2 [==============================] - 0s 71ms/step - loss: 0.3521 - accuracy: 0.8477
# Epoch 100/300
# 2/2 [==============================] - 0s 36ms/step - loss: 0.3557 - accuracy: 0.8411
# Epoch 101/300
# 2/2 [==============================] - 0s 32ms/step - loss: 0.3589 - accuracy: 0.8477
# Epoch 102/300
# 2/2 [==============================] - 0s 80ms/step - loss: 0.3509 - accuracy: 0.8444
# Epoch 103/300
# 2/2 [==============================] - 0s 77ms/step - loss: 0.3442 - accuracy: 0.8510
# Epoch 104/300
# 2/2 [==============================] - 0s 73ms/step - loss: 0.3404 - accuracy: 0.8642
# Epoch 105/300
# 2/2 [==============================] - 0s 31ms/step - loss: 0.3499 - accuracy: 0.8543
# Epoch 106/300
# 2/2 [==============================] - 0s 38ms/step - loss: 0.3689 - accuracy: 0.8411
# Epoch 107/300
# 2/2 [==============================] - 0s 34ms/step - loss: 0.3743 - accuracy: 0.8344
# Epoch 108/300
# 2/2 [==============================] - 0s 37ms/step - loss: 0.3520 - accuracy: 0.8576
# Epoch 109/300
# 2/2 [==============================] - 0s 102ms/step - loss: 0.3265 - accuracy: 0.8576
# Epoch 110/300
# 2/2 [==============================] - 0s 72ms/step - loss: 0.3208 - accuracy: 0.8642
# Epoch 111/300
# 2/2 [==============================] - 0s 31ms/step - loss: 0.3234 - accuracy: 0.8709
# Epoch 112/300
# 2/2 [==============================] - 0s 41ms/step - loss: 0.3374 - accuracy: 0.8477
# Epoch 113/300
# 2/2 [==============================] - 0s 40ms/step - loss: 0.3379 - accuracy: 0.8477
# Epoch 114/300
# 2/2 [==============================] - 0s 35ms/step - loss: 0.3247 - accuracy: 0.8675
# Epoch 115/300
# 2/2 [==============================] - 0s 81ms/step - loss: 0.3174 - accuracy: 0.8675
# Epoch 116/300
# 2/2 [==============================] - 0s 33ms/step - loss: 0.3277 - accuracy: 0.8841
# Epoch 117/300
# 2/2 [==============================] - 0s 34ms/step - loss: 0.3468 - accuracy: 0.8477
# Epoch 118/300
# 2/2 [==============================] - 0s 32ms/step - loss: 0.3357 - accuracy: 0.8742
# Epoch 119/300
# 2/2 [==============================] - 0s 37ms/step - loss: 0.3218 - accuracy: 0.8609
# Epoch 120/300
# 2/2 [==============================] - 0s 80ms/step - loss: 0.3117 - accuracy: 0.8709
# Epoch 121/300
# 2/2 [==============================] - 0s 94ms/step - loss: 0.3010 - accuracy: 0.8675
# Epoch 122/300
# 2/2 [==============================] - 0s 34ms/step - loss: 0.3053 - accuracy: 0.8709
# Epoch 123/300
# 2/2 [==============================] - 0s 37ms/step - loss: 0.3125 - accuracy: 0.8609
# Epoch 124/300
# 2/2 [==============================] - 0s 37ms/step - loss: 0.3109 - accuracy: 0.8675
# Epoch 125/300
# 2/2 [==============================] - 0s 42ms/step - loss: 0.3019 - accuracy: 0.8709
# Epoch 126/300
# 2/2 [==============================] - 0s 84ms/step - loss: 0.2907 - accuracy: 0.8907
# Epoch 127/300
# 2/2 [==============================] - 0s 37ms/step - loss: 0.2918 - accuracy: 0.8808
# Epoch 128/300
# 2/2 [==============================] - 0s 38ms/step - loss: 0.3075 - accuracy: 0.8874
# Epoch 129/300
# 2/2 [==============================] - 0s 33ms/step - loss: 0.3291 - accuracy: 0.8510
# Epoch 130/300
# 2/2 [==============================] - 0s 37ms/step - loss: 0.3215 - accuracy: 0.8675
# Epoch 131/300
# 2/2 [==============================] - 0s 42ms/step - loss: 0.2946 - accuracy: 0.8709
# Epoch 132/300
# 2/2 [==============================] - 0s 87ms/step - loss: 0.2820 - accuracy: 0.8907
# Epoch 133/300
# 2/2 [==============================] - 0s 86ms/step - loss: 0.2736 - accuracy: 0.8974
# Epoch 134/300
# 2/2 [==============================] - 0s 35ms/step - loss: 0.2851 - accuracy: 0.8742
# Epoch 135/300
# 2/2 [==============================] - 0s 35ms/step - loss: 0.2905 - accuracy: 0.8808
# Epoch 136/300
# 2/2 [==============================] - 0s 44ms/step - loss: 0.2828 - accuracy: 0.8709
# Epoch 137/300
# 2/2 [==============================] - 0s 33ms/step - loss: 0.2742 - accuracy: 0.8940
# Epoch 138/300
# 2/2 [==============================] - 0s 89ms/step - loss: 0.2673 - accuracy: 0.9007
# Epoch 139/300
# 2/2 [==============================] - 0s 35ms/step - loss: 0.2728 - accuracy: 0.8974
# Epoch 140/300
# 2/2 [==============================] - 0s 38ms/step - loss: 0.2940 - accuracy: 0.8907
# Epoch 141/300
# 2/2 [==============================] - 0s 36ms/step - loss: 0.3133 - accuracy: 0.8510
# Epoch 142/300
# 2/2 [==============================] - 0s 37ms/step - loss: 0.2940 - accuracy: 0.8940
# Epoch 143/300
# 2/2 [==============================] - 0s 81ms/step - loss: 0.2662 - accuracy: 0.8940
# Epoch 144/300
# 2/2 [==============================] - 0s 93ms/step - loss: 0.2564 - accuracy: 0.8974
# Epoch 145/300
# 2/2 [==============================] - 0s 89ms/step - loss: 0.2476 - accuracy: 0.9007
# Epoch 146/300
# 2/2 [==============================] - 0s 37ms/step - loss: 0.2593 - accuracy: 0.9007
# Epoch 147/300
# 2/2 [==============================] - 0s 33ms/step - loss: 0.2714 - accuracy: 0.8874
# Epoch 148/300
# 2/2 [==============================] - 0s 39ms/step - loss: 0.2719 - accuracy: 0.8841
# Epoch 149/300
# 2/2 [==============================] - 0s 34ms/step - loss: 0.2609 - accuracy: 0.9007
# Epoch 150/300
# 2/2 [==============================] - 0s 34ms/step - loss: 0.2499 - accuracy: 0.9073
# Epoch 151/300
# 2/2 [==============================] - 0s 37ms/step - loss: 0.2494 - accuracy: 0.9106
# Epoch 152/300
# 2/2 [==============================] - 0s 31ms/step - loss: 0.2620 - accuracy: 0.8940
# Epoch 153/300
# 2/2 [==============================] - 0s 32ms/step - loss: 0.2861 - accuracy: 0.8576
# Epoch 154/300
# 2/2 [==============================] - 0s 39ms/step - loss: 0.2795 - accuracy: 0.8974
# Epoch 155/300
# 2/2 [==============================] - 0s 45ms/step - loss: 0.2479 - accuracy: 0.8907
# Epoch 156/300
# 2/2 [==============================] - 0s 88ms/step - loss: 0.2374 - accuracy: 0.9205
# Epoch 157/300
# 2/2 [==============================] - 0s 76ms/step - loss: 0.2257 - accuracy: 0.9139
# Epoch 158/300
# 2/2 [==============================] - 0s 39ms/step - loss: 0.2318 - accuracy: 0.9106
# Epoch 159/300
# 2/2 [==============================] - 0s 34ms/step - loss: 0.2473 - accuracy: 0.9007
# Epoch 160/300
# 2/2 [==============================] - 0s 34ms/step - loss: 0.2629 - accuracy: 0.8907
# Epoch 161/300
# 2/2 [==============================] - 0s 35ms/step - loss: 0.2466 - accuracy: 0.8940
# Epoch 162/300
# 2/2 [==============================] - 0s 33ms/step - loss: 0.2282 - accuracy: 0.9172
# Epoch 163/300
# 2/2 [==============================] - 0s 76ms/step - loss: 0.2245 - accuracy: 0.9272
# Epoch 164/300
# 2/2 [==============================] - 0s 34ms/step - loss: 0.2320 - accuracy: 0.9040
# Epoch 165/300
# 2/2 [==============================] - 0s 35ms/step - loss: 0.2601 - accuracy: 0.8841
# Epoch 166/300
# 2/2 [==============================] - 0s 36ms/step - loss: 0.2624 - accuracy: 0.8974
# Epoch 167/300
# 2/2 [==============================] - 0s 32ms/step - loss: 0.2420 - accuracy: 0.8874
# Epoch 168/300
# 2/2 [==============================] - 0s 36ms/step - loss: 0.2365 - accuracy: 0.9172
# Epoch 169/300
# 2/2 [==============================] - 0s 72ms/step - loss: 0.2170 - accuracy: 0.9106
# Epoch 170/300
# 2/2 [==============================] - 0s 31ms/step - loss: 0.2206 - accuracy: 0.9338
# Epoch 171/300
# 2/2 [==============================] - 0s 72ms/step - loss: 0.2105 - accuracy: 0.9139
# Epoch 172/300
# 2/2 [==============================] - 0s 34ms/step - loss: 0.2234 - accuracy: 0.9205
# Epoch 173/300
# 2/2 [==============================] - 0s 35ms/step - loss: 0.2367 - accuracy: 0.9040
# Epoch 174/300
# 2/2 [==============================] - 0s 35ms/step - loss: 0.2307 - accuracy: 0.9040
# Epoch 175/300
# 2/2 [==============================] - 0s 36ms/step - loss: 0.2152 - accuracy: 0.9238
# Epoch 176/300
# 2/2 [==============================] - 0s 82ms/step - loss: 0.2003 - accuracy: 0.9338
# Epoch 177/300
# 2/2 [==============================] - 0s 33ms/step - loss: 0.2055 - accuracy: 0.9272
# Epoch 178/300
# 2/2 [==============================] - 0s 53ms/step - loss: 0.2290 - accuracy: 0.9106
# Epoch 179/300
# 2/2 [==============================] - 0s 35ms/step - loss: 0.2573 - accuracy: 0.8808
# Epoch 180/300
# 2/2 [==============================] - 0s 36ms/step - loss: 0.2521 - accuracy: 0.9040
# Epoch 181/300
# 2/2 [==============================] - 0s 34ms/step - loss: 0.2176 - accuracy: 0.8974
# Epoch 182/300
# 2/2 [==============================] - 0s 31ms/step - loss: 0.2141 - accuracy: 0.9305
# Epoch 183/300
# 2/2 [==============================] - 0s 75ms/step - loss: 0.1907 - accuracy: 0.9172
# Epoch 184/300
# 2/2 [==============================] - 0s 38ms/step - loss: 0.1926 - accuracy: 0.9338
# Epoch 185/300
# 2/2 [==============================] - 0s 36ms/step - loss: 0.1948 - accuracy: 0.9238
# Epoch 186/300
# 2/2 [==============================] - 0s 39ms/step - loss: 0.2129 - accuracy: 0.9238
# Epoch 187/300
# 2/2 [==============================] - 0s 36ms/step - loss: 0.2178 - accuracy: 0.9007
# Epoch 188/300
# 2/2 [==============================] - 0s 35ms/step - loss: 0.2037 - accuracy: 0.9238
# Epoch 189/300
# 2/2 [==============================] - 0s 113ms/step - loss: 0.1903 - accuracy: 0.9371
# Epoch 190/300
# 2/2 [==============================] - 0s 83ms/step - loss: 0.1821 - accuracy: 0.9437
# Epoch 191/300
# 2/2 [==============================] - 0s 32ms/step - loss: 0.1898 - accuracy: 0.9371
# Epoch 192/300
# 2/2 [==============================] - 0s 42ms/step - loss: 0.2111 - accuracy: 0.9172
# Epoch 193/300
# 2/2 [==============================] - 0s 31ms/step - loss: 0.2431 - accuracy: 0.8974
# Epoch 194/300
# 2/2 [==============================] - 0s 39ms/step - loss: 0.2443 - accuracy: 0.9007
# Epoch 195/300
# 2/2 [==============================] - 0s 33ms/step - loss: 0.2113 - accuracy: 0.8974
# Epoch 196/300
# 2/2 [==============================] - 0s 33ms/step - loss: 0.2096 - accuracy: 0.9305
# Epoch 197/300
# 2/2 [==============================] - 0s 76ms/step - loss: 0.1759 - accuracy: 0.9272
# Epoch 198/300
# 2/2 [==============================] - 0s 78ms/step - loss: 0.1743 - accuracy: 0.9470
# Epoch 199/300
# 2/2 [==============================] - 0s 88ms/step - loss: 0.1683 - accuracy: 0.9437
# Epoch 200/300
# 2/2 [==============================] - 0s 40ms/step - loss: 0.1801 - accuracy: 0.9437
# Epoch 201/300
# 2/2 [==============================] - 0s 36ms/step - loss: 0.1979 - accuracy: 0.9238
# Epoch 202/300
# 2/2 [==============================] - 0s 35ms/step - loss: 0.2009 - accuracy: 0.9205
# Epoch 203/300
# 2/2 [==============================] - 0s 35ms/step - loss: 0.1880 - accuracy: 0.9272
# Epoch 204/300
# 2/2 [==============================] - 0s 37ms/step - loss: 0.1710 - accuracy: 0.9470
# Epoch 205/300
# 2/2 [==============================] - 0s 77ms/step - loss: 0.1649 - accuracy: 0.9437
# Epoch 206/300
# 2/2 [==============================] - 0s 34ms/step - loss: 0.1748 - accuracy: 0.9437
# Epoch 207/300
# 2/2 [==============================] - 0s 36ms/step - loss: 0.2245 - accuracy: 0.8974
# Epoch 208/300
# 2/2 [==============================] - 0s 31ms/step - loss: 0.2626 - accuracy: 0.8874
# Epoch 209/300
# 2/2 [==============================] - 0s 34ms/step - loss: 0.2011 - accuracy: 0.9172
# Epoch 210/300
# 2/2 [==============================] - 0s 41ms/step - loss: 0.1712 - accuracy: 0.9437
# Epoch 211/300
# 2/2 [==============================] - 0s 81ms/step - loss: 0.1522 - accuracy: 0.9470
# Epoch 212/300
# 2/2 [==============================] - 0s 110ms/step - loss: 0.1509 - accuracy: 0.9570
# Epoch 213/300
# 2/2 [==============================] - 0s 32ms/step - loss: 0.1554 - accuracy: 0.9470
# Epoch 214/300
# 2/2 [==============================] - 0s 38ms/step - loss: 0.1739 - accuracy: 0.9404
# Epoch 215/300
# 2/2 [==============================] - 0s 33ms/step - loss: 0.2009 - accuracy: 0.9172
# Epoch 216/300
# 2/2 [==============================] - 0s 38ms/step - loss: 0.1975 - accuracy: 0.9238
# Epoch 217/300
# 2/2 [==============================] - 0s 46ms/step - loss: 0.1699 - accuracy: 0.9404
# Epoch 218/300
# 2/2 [==============================] - 0s 37ms/step - loss: 0.1581 - accuracy: 0.9636
# Epoch 219/300
# 2/2 [==============================] - 0s 38ms/step - loss: 0.1526 - accuracy: 0.9404
# Epoch 220/300
# 2/2 [==============================] - 0s 39ms/step - loss: 0.1798 - accuracy: 0.9470
# Epoch 221/300
# 2/2 [==============================] - 0s 43ms/step - loss: 0.1944 - accuracy: 0.9139
# Epoch 222/300
# 2/2 [==============================] - 0s 43ms/step - loss: 0.2234 - accuracy: 0.9272
# Epoch 223/300
# 2/2 [==============================] - 0s 36ms/step - loss: 0.1858 - accuracy: 0.9371
# Epoch 224/300
# 2/2 [==============================] - 0s 37ms/step - loss: 0.1711 - accuracy: 0.9338
# Epoch 225/300
# 2/2 [==============================] - 0s 35ms/step - loss: 0.1615 - accuracy: 0.9404
# Epoch 226/300
# 2/2 [==============================] - 0s 78ms/step - loss: 0.1508 - accuracy: 0.9437
# Epoch 227/300
# 2/2 [==============================] - 0s 89ms/step - loss: 0.1504 - accuracy: 0.9437
# Epoch 228/300
# 2/2 [==============================] - 0s 41ms/step - loss: 0.1514 - accuracy: 0.9470
# Epoch 229/300
# 2/2 [==============================] - 0s 37ms/step - loss: 0.1654 - accuracy: 0.9371
# Epoch 230/300
# 2/2 [==============================] - 0s 34ms/step - loss: 0.1836 - accuracy: 0.9305
# Epoch 231/300
# 2/2 [==============================] - 0s 33ms/step - loss: 0.1744 - accuracy: 0.9338
# Epoch 232/300
# 2/2 [==============================] - 0s 31ms/step - loss: 0.1711 - accuracy: 0.9503
# Epoch 233/300
# 2/2 [==============================] - 0s 74ms/step - loss: 0.1487 - accuracy: 0.9371
# Epoch 234/300
# 2/2 [==============================] - 0s 41ms/step - loss: 0.1607 - accuracy: 0.9570
# Epoch 235/300
# 2/2 [==============================] - 0s 35ms/step - loss: 0.1605 - accuracy: 0.9338
# Epoch 236/300
# 2/2 [==============================] - 0s 35ms/step - loss: 0.1821 - accuracy: 0.9404
# Epoch 237/300
# 2/2 [==============================] - 0s 38ms/step - loss: 0.1727 - accuracy: 0.9338
# Epoch 238/300
# 2/2 [==============================] - 0s 33ms/step - loss: 0.1531 - accuracy: 0.9371
# Epoch 239/300
# 2/2 [==============================] - 0s 76ms/step - loss: 0.1419 - accuracy: 0.9503
# Epoch 240/300
# 2/2 [==============================] - 0s 85ms/step - loss: 0.1393 - accuracy: 0.9437
# Epoch 241/300
# 2/2 [==============================] - 0s 40ms/step - loss: 0.1532 - accuracy: 0.9338
# Epoch 242/300
# 2/2 [==============================] - 0s 36ms/step - loss: 0.1662 - accuracy: 0.9437
# Epoch 243/300
# 2/2 [==============================] - 0s 33ms/step - loss: 0.1699 - accuracy: 0.9272
# Epoch 244/300
# 2/2 [==============================] - 0s 39ms/step - loss: 0.1710 - accuracy: 0.9470
# Epoch 245/300
# 2/2 [==============================] - 0s 31ms/step - loss: 0.1447 - accuracy: 0.9503
# Epoch 246/300
# 2/2 [==============================] - 0s 38ms/step - loss: 0.1545 - accuracy: 0.9603
# Epoch 247/300
# 2/2 [==============================] - 0s 33ms/step - loss: 0.1408 - accuracy: 0.9437
# Epoch 248/300
# 2/2 [==============================] - 0s 37ms/step - loss: 0.1591 - accuracy: 0.9536
# Epoch 249/300
# 2/2 [==============================] - 0s 35ms/step - loss: 0.1597 - accuracy: 0.9338
# Epoch 250/300
# 2/2 [==============================] - 0s 34ms/step - loss: 0.1533 - accuracy: 0.9404
# Epoch 251/300
# 2/2 [==============================] - 0s 73ms/step - loss: 0.1374 - accuracy: 0.9404
# Epoch 252/300
# 2/2 [==============================] - 0s 127ms/step - loss: 0.1304 - accuracy: 0.9570
# Epoch 253/300
# 2/2 [==============================] - 0s 36ms/step - loss: 0.1324 - accuracy: 0.9470
# Epoch 254/300
# 2/2 [==============================] - 0s 37ms/step - loss: 0.1412 - accuracy: 0.9404
# Epoch 255/300
# 2/2 [==============================] - 0s 37ms/step - loss: 0.1648 - accuracy: 0.9272
# Epoch 256/300
# 2/2 [==============================] - 0s 36ms/step - loss: 0.1774 - accuracy: 0.9338
# Epoch 257/300
# 2/2 [==============================] - 0s 36ms/step - loss: 0.1568 - accuracy: 0.9437
# Epoch 258/300
# 2/2 [==============================] - 0s 67ms/step - loss: 0.1506 - accuracy: 0.9636
# Epoch 259/300
# 2/2 [==============================] - 0s 179ms/step - loss: 0.1219 - accuracy: 0.9503
# Epoch 260/300
# 2/2 [==============================] - 0s 62ms/step - loss: 0.1326 - accuracy: 0.9603
# Epoch 261/300
# 2/2 [==============================] - 0s 66ms/step - loss: 0.1349 - accuracy: 0.9437
# Epoch 262/300
# 2/2 [==============================] - 0s 61ms/step - loss: 0.1563 - accuracy: 0.9570
# Epoch 263/300
# 2/2 [==============================] - 0s 65ms/step - loss: 0.1499 - accuracy: 0.9371
# Epoch 264/300
# 2/2 [==============================] - 0s 67ms/step - loss: 0.1323 - accuracy: 0.9536
# Epoch 265/300
# 2/2 [==============================] - 0s 202ms/step - loss: 0.1191 - accuracy: 0.9570
# Epoch 266/300
# 2/2 [==============================] - 0s 151ms/step - loss: 0.1175 - accuracy: 0.9536
# Epoch 267/300
# 2/2 [==============================] - 0s 91ms/step - loss: 0.1295 - accuracy: 0.9404
# Epoch 268/300
# 2/2 [==============================] - 0s 74ms/step - loss: 0.1537 - accuracy: 0.9371
# Epoch 269/300
# 2/2 [==============================] - 0s 83ms/step - loss: 0.1678 - accuracy: 0.9205
# Epoch 270/300
# 2/2 [==============================] - 0s 67ms/step - loss: 0.1583 - accuracy: 0.9470
# Epoch 271/300
# 2/2 [==============================] - 0s 124ms/step - loss: 0.1266 - accuracy: 0.9603
# Epoch 272/300
# 2/2 [==============================] - 0s 83ms/step - loss: 0.1270 - accuracy: 0.9669
# Epoch 273/300
# 2/2 [==============================] - 0s 117ms/step - loss: 0.1180 - accuracy: 0.9636
# Epoch 274/300
# 2/2 [==============================] - 0s 66ms/step - loss: 0.1380 - accuracy: 0.9536
# Epoch 275/300
# 2/2 [==============================] - 0s 81ms/step - loss: 0.1427 - accuracy: 0.9404
# Epoch 276/300
# 2/2 [==============================] - 0s 60ms/step - loss: 0.1338 - accuracy: 0.9570
# Epoch 277/300
# 2/2 [==============================] - 0s 226ms/step - loss: 0.1162 - accuracy: 0.9536
# Epoch 278/300
# 2/2 [==============================] - 0s 129ms/step - loss: 0.1081 - accuracy: 0.9669
# Epoch 279/300
# 2/2 [==============================] - 0s 166ms/step - loss: 0.1064 - accuracy: 0.9570
# Epoch 280/300
# 2/2 [==============================] - 0s 72ms/step - loss: 0.1111 - accuracy: 0.9570
# Epoch 281/300
# 2/2 [==============================] - 0s 58ms/step - loss: 0.1330 - accuracy: 0.9437
# Epoch 282/300
# 2/2 [==============================] - 0s 44ms/step - loss: 0.1602 - accuracy: 0.9371
# Epoch 283/300
# 2/2 [==============================] - 0s 93ms/step - loss: 0.1632 - accuracy: 0.9272
# Epoch 284/300
# 2/2 [==============================] - 0s 128ms/step - loss: 0.1514 - accuracy: 0.9503
# Epoch 285/300
# 2/2 [==============================] - 0s 74ms/step - loss: 0.1093 - accuracy: 0.9702
# Epoch 286/300
# 2/2 [==============================] - 0s 64ms/step - loss: 0.1196 - accuracy: 0.9702
# Epoch 287/300
# 2/2 [==============================] - 0s 50ms/step - loss: 0.1110 - accuracy: 0.9669
# Epoch 288/300
# 2/2 [==============================] - 0s 58ms/step - loss: 0.1295 - accuracy: 0.9570
# Epoch 289/300
# 2/2 [==============================] - 0s 69ms/step - loss: 0.1309 - accuracy: 0.9470
# Epoch 290/300
# 2/2 [==============================] - 0s 77ms/step - loss: 0.1201 - accuracy: 0.9603
# Epoch 291/300
# 2/2 [==============================] - 0s 114ms/step - loss: 0.1049 - accuracy: 0.9570
# Epoch 292/300
# 2/2 [==============================] - 0s 113ms/step - loss: 0.0975 - accuracy: 0.9735
# Epoch 293/300
# 2/2 [==============================] - 0s 127ms/step - loss: 0.0950 - accuracy: 0.9636
# Epoch 294/300
# 2/2 [==============================] - 0s 49ms/step - loss: 0.1000 - accuracy: 0.9603
# Epoch 295/300
# 2/2 [==============================] - 0s 58ms/step - loss: 0.1244 - accuracy: 0.9503
# Epoch 296/300
# 2/2 [==============================] - 0s 48ms/step - loss: 0.1603 - accuracy: 0.9437
# Epoch 297/300
# 2/2 [==============================] - 0s 47ms/step - loss: 0.1550 - accuracy: 0.9404
# Epoch 298/300
# 2/2 [==============================] - 0s 58ms/step - loss: 0.1303 - accuracy: 0.9603
# Epoch 299/300
# 2/2 [==============================] - 0s 110ms/step - loss: 0.0936 - accuracy: 0.9735
# Epoch 300/300
# 2/2 [==============================] - 0s 49ms/step - loss: 0.1027 - accuracy: 0.9702

# %%
#load model
model = keras.models.load_model(os.getcwd() + '/gdrive/My Drive/Model/weights.hdf5')

# %%
for i in range(1,6):
  stat_model_predict(model, x_test[:i*12], y_test[:i*12])
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#          0.0     0.0000    0.0000    0.0000         4
#          1.0     0.6667    1.0000    0.8000         8
#
#     accuracy                         0.6667        12
#    macro avg     0.3333    0.5000    0.4000        12
# weighted avg     0.4444    0.6667    0.5333        12
#               precision    recall  f1-score   support
#
#          0.0     0.6667    0.3636    0.4706        11
#          1.0     0.6111    0.8462    0.7097        13
#
#     accuracy                         0.6250        24
#    macro avg     0.6389    0.6049    0.5901        24
# weighted avg     0.6366    0.6250    0.6001        24
#               precision    recall  f1-score   support
#
#          0.0     0.7778    0.3684    0.5000        19
#          1.0     0.5556    0.8824    0.6818        17
#
#     accuracy                         0.6111        36
#    macro avg     0.6667    0.6254    0.5909        36
# weighted avg     0.6728    0.6111    0.5859        36
#               precision    recall  f1-score   support
#
#          0.0     0.6667    0.4800    0.5581        25
#          1.0     0.5667    0.7391    0.6415        23
#
#     accuracy                         0.6042        48
#    macro avg     0.6167    0.6096    0.5998        48
# weighted avg     0.6187    0.6042    0.5981        48
#               precision    recall  f1-score   support
#
#          0.0     0.5000    0.5000    0.5000        26
#          1.0     0.5667    0.5667    0.5667        30
#
#     accuracy                         0.5357        56
#    macro avg     0.5333    0.5333    0.5333        56
# weighted avg     0.5357    0.5357    0.5357        56

# %%
stat_model_predict(model, x_test, y_test)
;
# Out:
#               precision    recall  f1-score   support
#
#          0.0     0.5000    0.5000    0.5000        26
#          1.0     0.5667    0.5667    0.5667        30
#
#     accuracy                         0.5357        56
#    macro avg     0.5333    0.5333    0.5333        56
# weighted avg     0.5357    0.5357    0.5357        56
# ''

# %%
scaler = StandardScaler()
x = scaler.fit_transform(data[x_columns])
y_hat['y_hat_ann'] = stat_model_predict(model, x, data['price_next_week'])
# Out:
#               precision    recall  f1-score   support
#
#            0     0.8125    0.8034    0.8079       178
#            1     0.8077    0.8167    0.8122       180
#
#     accuracy                         0.8101       358
#    macro avg     0.8101    0.8100    0.8100       358
# weighted avg     0.8101    0.8101    0.8100       358

# %%
y_hat
# Out:
#      y_hat_ann
# 0            1
# 1            1
# 2            0
# 3            0
# 4            0
# ..         ...
# 353          0
# 354          0
# 355          0
# 356          0
# 357          0
#
# [358 rows x 1 columns]

# %%
week = data[['week', 'dates']]
week.reset_index(drop=True, inplace=True)
week.head()
# Out:
#                             week   dates
# 0   วันที่ 9 -13 กุมภาพันธ์ 2558  201507
# 1  วันที่ 16-20 กุมภาพันธ์ 2558   201508
# 2   วันที่ 23 - 27กุมภาพันธ์2558  201509
# 3      วันที่ 2 - 6 มีนาคม 2558   201510
# 4       วันที่ 9-13 มีนาคม 2558   201511

# %%
y_model = pd.DataFrame(data['price_next_week'])
y_model.head()
# Out:
#    price_next_week
# 0                1
# 1                1
# 2                0
# 3                0
# 4                0

# %%
y = pd.concat([week, y_model, y_hat], ignore_index = False, axis = 1)
y['dates'] = y['dates'].astype(str)

# %%
week_price = pd.read_csv('/content/gdrive/My Drive/Colab Notebooks/soybean_week_price.csv')
week_price = week_price[['Dates', 'PX_LAST']]
week_price = week_price.rename(columns={'Dates': 'dates', 'PX_LAST' : 'week_close_price'})

week_price['dates'] = week_price['dates'].apply(group_date)

week_price
# Out:
#        dates  week_close_price
# 0     200001            478.75
# 1     200002            496.25
# 2     200003            505.25
# 3     200004            523.50
# 4     200005            505.50
# ...      ...               ...
# 1153  202206           1583.00
# 1154  202207           1601.50
# 1155  202208           1590.25
# 1156  202209           1660.50
# 1157  202210           1676.00
#
# [1158 rows x 2 columns]

# %%
p_return = pd.merge_ordered(y, week_price, on='dates', fill_method='ffill', how='left')
p_return
# Out:
#                                       week   dates  price_next_week  \
# 0             วันที่ 9 -13 กุมภาพันธ์ 2558  201507                1
# 1            วันที่ 16-20 กุมภาพันธ์ 2558   201508                1
# 2             วันที่ 23 - 27กุมภาพันธ์2558  201509                0
# 3                วันที่ 2 - 6 มีนาคม 2558   201510                0
# 4                 วันที่ 9-13 มีนาคม 2558   201511                0
# ..                                     ...     ...              ...
# 353                 วันที่ 3-7 มกราคม 2565  202201                0
# 354               วันที่ 10-14 มกราคม 2565  202202                1
# 355               วันที่ 17-21 มกราคม 2565  202203                1
# 356               วันที่ 24-28 มกราคม 2565  202204                1
# 357   วันที่ 31 มกราคม - 4 กุมภาพันธ์ 2565  202205                1
#
#      y_hat_ann  week_close_price
# 0            1            990.50
# 1            1            999.25
# 2            0           1030.75
# 3            0            985.00
# 4            0            974.00
# ..         ...               ...
# 353          0           1410.25
# 354          0           1369.75
# 355          0           1414.25
# 356          0           1470.00
# 357          0           1553.50
#
# [358 rows x 5 columns]

# %%
p_return = get_data_from_years(p_return, [2021, 2022])

in_index = 0
current_state = p_return['y_hat_ann'][0]
p_return['%return'] = None

for idx in p_return.index:
  if p_return['y_hat_ann'][idx] != current_state or idx == len(p_return.index)-1:
    if current_state == 1:
      A = p_return['week_close_price'][idx]
      B = p_return['week_close_price'][in_index]
    else:
      A = p_return['week_close_price'][in_index]
      B = p_return['week_close_price'][idx]

    p_return.loc[idx, '%return'] = (A - B)*100 / B

    in_index = idx
    current_state = p_return['y_hat_ann'][idx]

p_return.loc[p_return.index[-1], '%return'] += 0.25
p_return
# Out:
#                                      week   dates  price_next_week  y_hat_ann  \
# 0                วันที่ 4 - 8 มกราคม 2564  202101                1          0
# 1                วันที่ 11-15 มกราคม 2564  202102                0          0
# 2                วันที่ 18-22 มกราคม 2564  202103                0          0
# 3                วันที่ 25-29 มกราคม 2564  202104                1          1
# 4              วันที่ 1-5 กุมภาพันธ์ 2564  202105                1          0
# 5             วันที่ 8-11 กุมภาพันธ์ 2564  202106                1          0
# 6            วันที่ 15-19 กุมภาพันธ์ 2564  202107                1          1
# 7            วันที่ 22-25 กุมภาพันธ์ 2564  202108                1          1
# 8                  วันที่ 1-5 มีนาคม 2564  202109                1          1
# 9                 วันที่ 8-12 มีนาคม 2564  202110                0          1
# 10               วันที่ 15-19 มีนาคม 2564  202111                1          0
# 11               วันที่ 22-26 มีนาคม 2564  202112                0          1
# 12       วันที่ 29 มีนาคม - 2 เมษายน 2564  202113                1          0
# 13                 วันที่ 5-9 เมษายน 2564  202114                0          0
# 14               วันที่ 12-16 เมษายน 2564  202115                1          0
# 15               วันที่ 19-23 เมษายน 2564  202116                1          1
# 16               วันที่ 26-30 เมษายน 2564  202117                0          0
# 17                วันที่ 3-7 พฤษภาคม 2564  202118                1          0
# 18              วันที่ 10-14 พฤษภาคม 2564  202119                0          0
# 19              วันที่ 17-21 พฤษภาคม 2564  202120                0          0
# 20              วันที่ 24-28 พฤษภาคม 2564  202121                1          0
# 21    วันที่ 31 พฤษภาคม - 4 มิถุนายน 2564  202122                0          0
# 22              วันที่ 7-11 มิถุนายน 2564  202123                0          0
# 23             วันที่ 14-18 มิถุนายน 2564  202124                0          0
# 24             วันที่ 21-25 มิถุนายน 2564  202125                1          0
# 25    วันที่ 28 มิถุนายน - 2 กรกฎาคม 2564  202126                0          0
# 26                วันที่ 5-9 กรกฎาคม 2564  202127                1          0
# 27              วันที่ 12-16 กรกฎาคม 2564  202128                0          0
# 28              วันที่ 19-23 กรกฎาคม 2564  202129                0          0
# 29              วันที่ 26-30 กรกฎาคม 2564  202130                0          0
# 30                วันที่ 2-6 สิงหาคม 2564  202131                1          0
# 31               วันที่ 9-13 สิงหาคม 2564  202132                0          0
# 32              วันที่ 23-27 สิงหาคม 2564  202134                0          0
# 33     วันที่ 30 สิงหาคม - 3 กันยายน 2564  202135                0          0
# 34               วันที่ 6-10 กันยายน 2564  202136                1          0
# 35              วันที่ 13-17 กันยายน 2564  202137                0          1
# 36              วันที่ 20-24 กันยายน 2564  202138                0          0
# 37      วันที่ 27 กันยายน - 1 ตุลาคม 2564  202139                0          1
# 38               วันที่ 4 - 8 ตุลาคม 2564  202140                0          0
# 39               วันที่ 11-15 ตุลาคม 2564  202141                1          0
# 40               วันที่ 18-21 ตุลาคม 2564  202142                1          0
# 41               วันที่ 25-29 ตุลาคม 2564  202143                0          0
# 42              วันที่ 1-5 พฤศจิกายน 2564  202144                0          0
# 43             วันที่ 8-12 พฤศจิกายน 2564  202145                1          0
# 44            วันที่ 15-19 พฤศจิกายน 2564  202146                1          0
# 45            วันที่ 22-26 พฤศจิกายน 2564  202147                0          0
# 46   วันที่ 29 พฤศจิกายน - 3 ธันวาคม 2564  202148                1          0
# 47               วันที่ 6-10 ธันวาคม 2564  202149                1          0
# 48              วันที่ 13-17 ธันวาคม 2564  202150                1          0
# 49              วันที่ 20-24 ธันวาคม 2564  202151                1          0
# 50              วันที่ 27-29 ธันวาคม 2564  202152                1          0
# 51                 วันที่ 3-7 มกราคม 2565  202201                0          0
# 52               วันที่ 10-14 มกราคม 2565  202202                1          0
# 53               วันที่ 17-21 มกราคม 2565  202203                1          0
# 54               วันที่ 24-28 มกราคม 2565  202204                1          0
# 55   วันที่ 31 มกราคม - 4 กุมภาพันธ์ 2565  202205                1          0
#
#     week_close_price    %return
# 0            1374.75       None
# 1            1416.75       None
# 2            1311.75       None
# 3            1370.00   0.346715
# 4            1366.75  -0.237226
# 5            1372.00       None
# 6            1377.25  -0.762389
# 7            1405.25       None
# 8            1430.00       None
# 9            1413.25       None
# 10           1416.25    2.83173
# 11           1400.50   1.124598
# 12           1402.00   0.107105
# 13           1403.00       None
# 14           1433.25       None
# 15           1539.75  -8.946258
# 16           1571.00    2.02955
# 17           1589.75       None
# 18           1586.25       None
# 19           1526.25       None
# 20           1530.50       None
# 21           1583.75       None
# 22           1508.50       None
# 23           1396.00       None
# 24           1329.75       None
# 25           1433.25       None
# 26           1379.25       None
# 27           1454.75       None
# 28           1401.00       None
# 29           1414.75       None
# 30           1344.25       None
# 31           1373.00       None
# 32           1359.25       None
# 33           1292.00       None
# 34           1286.50       None
# 35           1284.00  22.352025
# 36           1285.00   0.077882
# 37           1246.50   3.088648
# 38           1243.00  -0.280786
# 39           1217.75       None
# 40           1220.50       None
# 41           1235.75       None
# 42           1205.50       None
# 43           1244.25       None
# 44           1263.25       None
# 45           1252.75       None
# 46           1267.25       None
# 47           1267.75       None
# 48           1285.25       None
# 49           1332.00       None
# 50           1328.75       None
# 51           1410.25       None
# 52           1369.75       None
# 53           1414.25       None
# 54           1470.00       None
# 55           1553.50 -19.737126

# %%
p_return['%return_after_comm'] = p_return['%return'].apply(lambda x : None if x is None else x-0.5)
p_return
# Out:
#                                      week   dates  price_next_week  y_hat_ann  \
# 0                วันที่ 4 - 8 มกราคม 2564  202101                1          0
# 1                วันที่ 11-15 มกราคม 2564  202102                0          0
# 2                วันที่ 18-22 มกราคม 2564  202103                0          0
# 3                วันที่ 25-29 มกราคม 2564  202104                1          1
# 4              วันที่ 1-5 กุมภาพันธ์ 2564  202105                1          0
# 5             วันที่ 8-11 กุมภาพันธ์ 2564  202106                1          0
# 6            วันที่ 15-19 กุมภาพันธ์ 2564  202107                1          1
# 7            วันที่ 22-25 กุมภาพันธ์ 2564  202108                1          1
# 8                  วันที่ 1-5 มีนาคม 2564  202109                1          1
# 9                 วันที่ 8-12 มีนาคม 2564  202110                0          1
# 10               วันที่ 15-19 มีนาคม 2564  202111                1          0
# 11               วันที่ 22-26 มีนาคม 2564  202112                0          1
# 12       วันที่ 29 มีนาคม - 2 เมษายน 2564  202113                1          0
# 13                 วันที่ 5-9 เมษายน 2564  202114                0          0
# 14               วันที่ 12-16 เมษายน 2564  202115                1          0
# 15               วันที่ 19-23 เมษายน 2564  202116                1          1
# 16               วันที่ 26-30 เมษายน 2564  202117                0          0
# 17                วันที่ 3-7 พฤษภาคม 2564  202118                1          0
# 18              วันที่ 10-14 พฤษภาคม 2564  202119                0          0
# 19              วันที่ 17-21 พฤษภาคม 2564  202120                0          0
# 20              วันที่ 24-28 พฤษภาคม 2564  202121                1          0
# 21    วันที่ 31 พฤษภาคม - 4 มิถุนายน 2564  202122                0          0
# 22              วันที่ 7-11 มิถุนายน 2564  202123                0          0
# 23             วันที่ 14-18 มิถุนายน 2564  202124                0          0
# 24             วันที่ 21-25 มิถุนายน 2564  202125                1          0
# 25    วันที่ 28 มิถุนายน - 2 กรกฎาคม 2564  202126                0          0
# 26                วันที่ 5-9 กรกฎาคม 2564  202127                1          0
# 27              วันที่ 12-16 กรกฎาคม 2564  202128                0          0
# 28              วันที่ 19-23 กรกฎาคม 2564  202129                0          0
# 29              วันที่ 26-30 กรกฎาคม 2564  202130                0          0
# 30                วันที่ 2-6 สิงหาคม 2564  202131                1          0
# 31               วันที่ 9-13 สิงหาคม 2564  202132                0          0
# 32              วันที่ 23-27 สิงหาคม 2564  202134                0          0
# 33     วันที่ 30 สิงหาคม - 3 กันยายน 2564  202135                0          0
# 34               วันที่ 6-10 กันยายน 2564  202136                1          0
# 35              วันที่ 13-17 กันยายน 2564  202137                0          1
# 36              วันที่ 20-24 กันยายน 2564  202138                0          0
# 37      วันที่ 27 กันยายน - 1 ตุลาคม 2564  202139                0          1
# 38               วันที่ 4 - 8 ตุลาคม 2564  202140                0          0
# 39               วันที่ 11-15 ตุลาคม 2564  202141                1          0
# 40               วันที่ 18-21 ตุลาคม 2564  202142                1          0
# 41               วันที่ 25-29 ตุลาคม 2564  202143                0          0
# 42              วันที่ 1-5 พฤศจิกายน 2564  202144                0          0
# 43             วันที่ 8-12 พฤศจิกายน 2564  202145                1          0
# 44            วันที่ 15-19 พฤศจิกายน 2564  202146                1          0
# 45            วันที่ 22-26 พฤศจิกายน 2564  202147                0          0
# 46   วันที่ 29 พฤศจิกายน - 3 ธันวาคม 2564  202148                1          0
# 47               วันที่ 6-10 ธันวาคม 2564  202149                1          0
# 48              วันที่ 13-17 ธันวาคม 2564  202150                1          0
# 49              วันที่ 20-24 ธันวาคม 2564  202151                1          0
# 50              วันที่ 27-29 ธันวาคม 2564  202152                1          0
# 51                 วันที่ 3-7 มกราคม 2565  202201                0          0
# 52               วันที่ 10-14 มกราคม 2565  202202                1          0
# 53               วันที่ 17-21 มกราคม 2565  202203                1          0
# 54               วันที่ 24-28 มกราคม 2565  202204                1          0
# 55   วันที่ 31 มกราคม - 4 กุมภาพันธ์ 2565  202205                1          0
#
#     week_close_price    %return  %return_after_comm
# 0            1374.75       None                 NaN
# 1            1416.75       None                 NaN
# 2            1311.75       None                 NaN
# 3            1370.00   0.346715           -0.153285
# 4            1366.75  -0.237226           -0.737226
# 5            1372.00       None                 NaN
# 6            1377.25  -0.762389           -1.262389
# 7            1405.25       None                 NaN
# 8            1430.00       None                 NaN
# 9            1413.25       None                 NaN
# 10           1416.25    2.83173            2.331730
# 11           1400.50   1.124598            0.624598
# 12           1402.00   0.107105           -0.392895
# 13           1403.00       None                 NaN
# 14           1433.25       None                 NaN
# 15           1539.75  -8.946258           -9.446258
# 16           1571.00    2.02955            1.529550
# 17           1589.75       None                 NaN
# 18           1586.25       None                 NaN
# 19           1526.25       None                 NaN
# 20           1530.50       None                 NaN
# 21           1583.75       None                 NaN
# 22           1508.50       None                 NaN
# 23           1396.00       None                 NaN
# 24           1329.75       None                 NaN
# 25           1433.25       None                 NaN
# 26           1379.25       None                 NaN
# 27           1454.75       None                 NaN
# 28           1401.00       None                 NaN
# 29           1414.75       None                 NaN
# 30           1344.25       None                 NaN
# 31           1373.00       None                 NaN
# 32           1359.25       None                 NaN
# 33           1292.00       None                 NaN
# 34           1286.50       None                 NaN
# 35           1284.00  22.352025           21.852025
# 36           1285.00   0.077882           -0.422118
# 37           1246.50   3.088648            2.588648
# 38           1243.00  -0.280786           -0.780786
# 39           1217.75       None                 NaN
# 40           1220.50       None                 NaN
# 41           1235.75       None                 NaN
# 42           1205.50       None                 NaN
# 43           1244.25       None                 NaN
# 44           1263.25       None                 NaN
# 45           1252.75       None                 NaN
# 46           1267.25       None                 NaN
# 47           1267.75       None                 NaN
# 48           1285.25       None                 NaN
# 49           1332.00       None                 NaN
# 50           1328.75       None                 NaN
# 51           1410.25       None                 NaN
# 52           1369.75       None                 NaN
# 53           1414.25       None                 NaN
# 54           1470.00       None                 NaN
# 55           1553.50 -19.737126          -20.237126

# %%
np.mean(p_return['%return_after_comm'])/np.std(p_return['%return_after_comm'], ddof=1)
# Out:
# -0.038105337396843984

# %%
p_return['%return_after_comm'].sum()
# Out:
# -4.5055314542859435

# %%
all_years = [2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022]
split_index = 6

summary = {
    'year' : [],
    '%return_after_comm' : [],
    'profit' : [],
    'loss' : [],
    'MDD' : []
}

for year in all_years:
  current_year_data = get_data_from_years(p_return, [year])
  summary['year'].append(year)
  summary['%return_after_comm'].append(round(current_year_data['%return_after_comm'].sum(), 2))
  summary['MDD'].append(abs(round(current_year_data['%return'].min(), 2)))
  summary['profit'].append(len(current_year_data[current_year_data['%return_after_comm'] >= 0]))
  summary['loss'].append(len(current_year_data[current_year_data['%return_after_comm'] < 0]))

# %%
summary = pd.DataFrame(summary)
summary
# Out:
#    year  %return_after_comm  profit  loss    MDD
# 0  2015                0.00       0     0    NaN
# 1  2016                0.00       0     0    NaN
# 2  2017                0.00       0     0    NaN
# 3  2018                0.00       0     0    NaN
# 4  2019                0.00       0     0    NaN
# 5  2020                0.00       0     0    NaN
# 6  2021               15.73       5     7   8.95
# 7  2022              -20.24       0     1  19.74

# %%
for idx in summary['profit'].index, summary['loss'].index:

  A = summary['profit'][idx]
  B = summary['loss'][idx]

  summary.loc[idx, 'accuracy'] = round((A / ( A + B ))*100, 2)

summary
# Out:
#    year  %return_after_comm  profit  loss    MDD  accuracy
# 0  2015                0.00       0     0    NaN       NaN
# 1  2016                0.00       0     0    NaN       NaN
# 2  2017                0.00       0     0    NaN       NaN
# 3  2018                0.00       0     0    NaN       NaN
# 4  2019                0.00       0     0    NaN       NaN
# 5  2020                0.00       0     0    NaN       NaN
# 6  2021               15.73       5     7   8.95     41.67
# 7  2022              -20.24       0     1  19.74      0.00

# %%
(summary['profit'].sum()/(summary['profit'].sum()+summary['loss'].sum()))*100
# Out:
# 38.46153846153847
