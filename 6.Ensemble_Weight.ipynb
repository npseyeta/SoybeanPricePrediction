# %%
#Connect with Drive
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import os
import datetime

import pandas as pd
import numpy as np
from numpy import array
import random

from sklearn.preprocessing import LabelEncoder, StandardScaler

from sklearn.pipeline import make_pipeline

from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn import svm
import tensorflow as tf
seed_value= 0
os.environ['PYTHONHASHSEED']=str(seed_value)
random.seed(seed_value)
np.random.seed(seed_value)
tf.random.set_seed(seed_value)
session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
tf.compat.v1.keras.backend.set_session(sess)
from tensorflow import keras

from sklearn.ensemble import VotingClassifier

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Flatten, Dense
from keras.wrappers.scikit_learn import KerasClassifier

from sklearn.metrics import classification_report ,confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

# %%
def get_data_from_years(dataframe, wanted_years):
  assert type(wanted_years) is list
  assert len(wanted_years) > 0

  idx = []
  for index, row in dataframe.iterrows():
    if int(str(row['dates'])[:4]) in wanted_years:
      idx.append(index)

  return pd.DataFrame(dataframe.iloc[idx]).reset_index(drop=True)

def group_date(date):
  date = date.strip()
  d, m, y = date.split('/')
  year, week, weekday = datetime.date(int(y), int(m), int(d)).isocalendar()
  return str(year) + str(week).zfill(2)

# %%
def stat_model_predict(clf, x, y):
 
  predictions = clf.predict(x)
  y_hat = pd.DataFrame(predictions)

  print(classification_report(y, predictions, digits=4))

  cm = confusion_matrix(y, predictions)
  disp = ConfusionMatrixDisplay(confusion_matrix=cm)
  disp.plot()
  plt.show()

  return y_hat

data = data.reset_index(drop=True)

all_years = [2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022]
split_index = 6

model_train = get_data_from_years(data, all_years[:split_index])
model_test = get_data_from_years(data, all_years[6:])

# %%
data = pd.read_csv('/content/gdrive/My Drive/Colab Notebooks/soybean_dataset.csv')
data
# Out:
#                                       week   dates  price_next_week  \
# 0             วันที่ 9 -13 กุมภาพันธ์ 2558  201507                1
# 1            วันที่ 16-20 กุมภาพันธ์ 2558   201508                1
# 2             วันที่ 23 - 27กุมภาพันธ์2558  201509                0
# 3                วันที่ 2 - 6 มีนาคม 2558   201510                0
# 4                 วันที่ 9-13 มีนาคม 2558   201511                0
# ..                                     ...     ...              ...
# 353                 วันที่ 3-7 มกราคม 2565  202201                0
# 354               วันที่ 10-14 มกราคม 2565  202202                1
# 355               วันที่ 17-21 มกราคม 2565  202203                1
# 356               วันที่ 24-28 มกราคม 2565  202204                1
# 357   วันที่ 31 มกราคม - 4 กุมภาพันธ์ 2565  202205                1
#
#      sum_c_vec  sum_tf_vec  news_price       MACD  MACD_SIGNAL  MACD_DIFF  \
# 0          115    6.063669          -1 -10.640456   -12.772359   2.131903
# 1          107    5.812786           0  -3.022899    -8.237728   5.214829
# 2          109    5.753888           0   2.948086    -2.374953   5.323039
# 3           92    5.227960           0   4.384361     2.591326   1.793035
# 4          100    5.703614           0  -1.004628     1.145109  -2.149738
# ..         ...         ...         ...        ...          ...        ...
# 353        196    8.822123           1  30.709619    24.604390   6.105229
# 354        240    8.600711           1  32.286825    30.261029   2.025796
# 355        191    8.671932           0  26.811105    28.807734  -1.996629
# 356        189    8.306811           0  29.307491    28.483037   0.824454
# 357        222    8.579548           1  45.743451    36.057292   9.686159
#
#          TAS_K  ...  Crushing_Million Bushels  Ending Stocks_Million Bushels  \
# 0    40.442610  ...                    1795.0                          385.0
# 1    81.127346  ...                    1795.0                          385.0
# 2    82.485961  ...                    1795.0                          385.0
# 3    45.347177  ...                    1795.0                          385.0
# 4    25.504981  ...                    1795.0                          385.0
# ..         ...  ...                       ...                            ...
# 353  94.230787  ...                    2190.0                          340.0
# 354  80.174787  ...                    2190.0                          350.0
# 355  81.269727  ...                    2190.0                          350.0
# 356  87.770796  ...                    2190.0                          350.0
# 357  93.508507  ...                    2190.0                          350.0
#
#      Exports_Million Bushels  Imports_Million Bushels  \
# 0                     1790.0                     25.0
# 1                     1790.0                     25.0
# 2                     1790.0                     25.0
# 3                     1790.0                     25.0
# 4                     1790.0                     25.0
# ..                       ...                      ...
# 353                   2050.0                     15.0
# 354                   2050.0                     15.0
# 355                   2050.0                     15.0
# 356                   2050.0                     15.0
# 357                   2050.0                     15.0
#
#      Production_Million Bushels  Residual Use_Million Bushels  \
# 0                        3969.0                          24.0
# 1                        3969.0                          24.0
# 2                        3969.0                          24.0
# 3                        3969.0                          24.0
# 4                        3969.0                          24.0
# ..                          ...                           ...
# 353                      4425.0                          15.0
# 354                      4435.0                          16.0
# 355                      4435.0                          16.0
# 356                      4435.0                          16.0
# 357                      4435.0                          16.0
#
#      Seed Use_Million Bushels  Total demand_Million Bushels  \
# 0                        92.0                        3701.0
# 1                        92.0                        3701.0
# 2                        92.0                        3701.0
# 3                        92.0                        3701.0
# 4                        92.0                        3701.0
# ..                        ...                           ...
# 353                     102.0                        4356.0
# 354                     102.0                        4357.0
# 355                     102.0                        4357.0
# 356                     102.0                        4357.0
# 357                     102.0                        4357.0
#
#      Total Supply_Million Bushels  Yield_Bushels/Acre
# 0                          4086.0                47.8
# 1                          4086.0                47.8
# 2                          4086.0                47.8
# 3                          4086.0                47.8
# 4                          4086.0                47.8
# ..                            ...                 ...
# 353                        4696.0                51.2
# 354                        4707.0                51.4
# 355                        4707.0                51.4
# 356                        4707.0                51.4
# 357                        4707.0                51.4
#
# [358 rows x 34 columns]

# %%
x_columns = ['sum_c_vec', 'sum_tf_vec','news_price', 'MACD', 'MACD_SIGNAL', 
             'MACD_DIFF', 'TAS_K', 'TAS_D', 'TAS_DS', 'TAS_DSS', 'CMCI',
             'RSI', 'BB_MA', 'BB_UPPER', 'BB_LOWER', 'BB_WIDTH', 'BB_PERCENT',
             'Area Harvested_Million Acres', 'Area Planted_Million Acres',
             'Average Farm Price_US Dollars/Bushel', 'Begining Stocks_Million Bushels',
             'Crushing_Million Bushels', 'Ending Stocks_Million Bushels',
             'Exports_Million Bushels', 'Imports_Million Bushels', 'Production_Million Bushels',
             'Residual Use_Million Bushels', 'Seed Use_Million Bushels', 'Total demand_Million Bushels',
             'Total Supply_Million Bushels', 'Yield_Bushels/Acre']

y_train = model_train['price_next_week']
x_train = model_train[x_columns]

y_test = model_test['price_next_week']
x_test = model_test[x_columns]

y_hat = pd.DataFrame()

label = LabelEncoder()
y_train = label.fit_transform(y_train).astype(float)
y_test = label.fit_transform(y_test).astype(float)

# %%
clf1 = LogisticRegression()
clf2 = make_pipeline(StandardScaler(), KNeighborsClassifier(n_neighbors=1, weights='distance'))
clf3 = make_pipeline(StandardScaler(), svm.SVC(kernel='linear', probability=True))

# create model
def create_model():
  model = Sequential()
  model.add(Dense(x_train.shape[1], activation='relu', input_dim=x_train.shape[1]))
  model.add(Dense(128))
  model.add(Dense(64))
  model.add(Dense(32))
  model.add(Dense(16, activation='relu'))
  model.add(Dense(1, activation='sigmoid'))
  model.compile(loss='binary_crossentropy', metrics=['accuracy'], run_eagerly=True)
  return model
keras_model = KerasClassifier(build_fn=create_model)
keras_model._estimator_type = "classifier" 

clf4 = make_pipeline(StandardScaler(), keras_model)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: DeprecationWarning: KerasClassifier is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   app.launch_new_instance()

# %%
accuracy = np.array([0.5000, 0.4464, 0.4464, 0.5357])
accuracy/=sum(accuracy)
accuracy
# Out:
# array([0.25926886, 0.23147524, 0.23147524, 0.27778066])

# %%
eclf = VotingClassifier(estimators=[('logit', clf1), ('knn', clf2), ('svm', clf3), ('keras_model', clf4)], voting='soft', weights=accuracy)
eclf = eclf.fit(x_train, y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# 10/10 [==============================] - 1s 28ms/step - loss: 0.7163 - accuracy: 0.4735

# %%
for i in range(1,6):
  stat_model_predict(eclf, x_test[:i*12], y_test[:i*12])
# Out:
#               precision    recall  f1-score   support
#
#          0.0     0.5000    0.2500    0.3333         4
#          1.0     0.7000    0.8750    0.7778         8
#
#     accuracy                         0.6667        12
#    macro avg     0.6000    0.5625    0.5556        12
# weighted avg     0.6333    0.6667    0.6296        12
#               precision    recall  f1-score   support
#
#          0.0     0.6667    0.5455    0.6000        11
#          1.0     0.6667    0.7692    0.7143        13
#
#     accuracy                         0.6667        24
#    macro avg     0.6667    0.6573    0.6571        24
# weighted avg     0.6667    0.6667    0.6619        24
#               precision    recall  f1-score   support
#
#          0.0     0.6667    0.5263    0.5882        19
#          1.0     0.5714    0.7059    0.6316        17
#
#     accuracy                         0.6111        36
#    macro avg     0.6190    0.6161    0.6099        36
# weighted avg     0.6217    0.6111    0.6087        36
#               precision    recall  f1-score   support
#
#          0.0     0.5882    0.4000    0.4762        25
#          1.0     0.5161    0.6957    0.5926        23
#
#     accuracy                         0.5417        48
#    macro avg     0.5522    0.5478    0.5344        48
# weighted avg     0.5537    0.5417    0.5320        48
#               precision    recall  f1-score   support
#
#          0.0     0.5556    0.3846    0.4545        26
#          1.0     0.5789    0.7333    0.6471        30
#
#     accuracy                         0.5714        56
#    macro avg     0.5673    0.5590    0.5508        56
# weighted avg     0.5681    0.5714    0.5577        56

# %%
stat_model_predict(eclf, x_test, y_test)
;
# Out:
#               precision    recall  f1-score   support
#
#          0.0     0.5556    0.3846    0.4545        26
#          1.0     0.5789    0.7333    0.6471        30
#
#     accuracy                         0.5714        56
#    macro avg     0.5673    0.5590    0.5508        56
# weighted avg     0.5681    0.5714    0.5577        56
# ''

# %%
y_hat['y_hat_w'] = stat_model_predict(eclf, data[x_columns], data['price_next_week'])
# Out:
#               precision    recall  f1-score   support
#
#            0     0.9458    0.8820    0.9128       178
#            1     0.8906    0.9500    0.9194       180
#
#     accuracy                         0.9162       358
#    macro avg     0.9182    0.9160    0.9161       358
# weighted avg     0.9180    0.9162    0.9161       358

# %%
y_hat
# Out:
#      y_hat_w
# 0        1.0
# 1        1.0
# 2        0.0
# 3        0.0
# 4        0.0
# ..       ...
# 353      1.0
# 354      0.0
# 355      1.0
# 356      1.0
# 357      1.0
#
# [358 rows x 1 columns]

# %%
week = data[['week', 'dates']]
week.reset_index(drop=True, inplace=True)
week.head()
# Out:
#                             week   dates
# 0   วันที่ 9 -13 กุมภาพันธ์ 2558  201507
# 1  วันที่ 16-20 กุมภาพันธ์ 2558   201508
# 2   วันที่ 23 - 27กุมภาพันธ์2558  201509
# 3      วันที่ 2 - 6 มีนาคม 2558   201510
# 4       วันที่ 9-13 มีนาคม 2558   201511

# %%
y_model = pd.DataFrame(data['price_next_week'])
y_model.head()
# Out:
#    price_next_week
# 0                1
# 1                1
# 2                0
# 3                0
# 4                0

# %%
y = pd.concat([week, y_model, y_hat], ignore_index = False, axis = 1)
y['dates'] = y['dates'].astype(str)

# %%
week_price = pd.read_csv('/content/gdrive/My Drive/Colab Notebooks/soybean_week_price.csv')
week_price = week_price[['Dates', 'PX_LAST']]
week_price = week_price.rename(columns={'Dates': 'dates', 'PX_LAST' : 'week_close_price'})

week_price['dates'] = week_price['dates'].apply(group_date)

week_price
# Out:
#        dates  week_close_price
# 0     200001            478.75
# 1     200002            496.25
# 2     200003            505.25
# 3     200004            523.50
# 4     200005            505.50
# ...      ...               ...
# 1153  202206           1583.00
# 1154  202207           1601.50
# 1155  202208           1590.25
# 1156  202209           1660.50
# 1157  202210           1676.00
#
# [1158 rows x 2 columns]

# %%
p_return = pd.merge_ordered(y, week_price, on='dates', fill_method='ffill', how='left')
p_return
# Out:
#                                       week   dates  price_next_week  y_hat_w  \
# 0             วันที่ 9 -13 กุมภาพันธ์ 2558  201507                1      1.0
# 1            วันที่ 16-20 กุมภาพันธ์ 2558   201508                1      1.0
# 2             วันที่ 23 - 27กุมภาพันธ์2558  201509                0      0.0
# 3                วันที่ 2 - 6 มีนาคม 2558   201510                0      0.0
# 4                 วันที่ 9-13 มีนาคม 2558   201511                0      0.0
# ..                                     ...     ...              ...      ...
# 353                 วันที่ 3-7 มกราคม 2565  202201                0      1.0
# 354               วันที่ 10-14 มกราคม 2565  202202                1      0.0
# 355               วันที่ 17-21 มกราคม 2565  202203                1      1.0
# 356               วันที่ 24-28 มกราคม 2565  202204                1      1.0
# 357   วันที่ 31 มกราคม - 4 กุมภาพันธ์ 2565  202205                1      1.0
#
#      week_close_price
# 0              990.50
# 1              999.25
# 2             1030.75
# 3              985.00
# 4              974.00
# ..                ...
# 353           1410.25
# 354           1369.75
# 355           1414.25
# 356           1470.00
# 357           1553.50
#
# [358 rows x 5 columns]

# %%
p_return = get_data_from_years(p_return, [2021, 2022])

in_index = 0
current_state = p_return['y_hat_w'][0]
p_return['%return'] = None

for idx in p_return.index:
  if p_return['y_hat_w'][idx] != current_state or idx == len(p_return.index)-1:
    if current_state == 1:
      A = p_return['week_close_price'][idx]
      B = p_return['week_close_price'][in_index]
    else:
      A = p_return['week_close_price'][in_index]
      B = p_return['week_close_price'][idx]

    p_return.loc[idx, '%return'] = (A - B)*100 / B

    in_index = idx
    current_state = p_return['y_hat_w'][idx]

p_return.loc[p_return.index[-1], '%return'] += 0.25
p_return
# Out:
#                                      week   dates  price_next_week  y_hat_w  \
# 0                วันที่ 4 - 8 มกราคม 2564  202101                1      1.0
# 1                วันที่ 11-15 มกราคม 2564  202102                0      1.0
# 2                วันที่ 18-22 มกราคม 2564  202103                0      0.0
# 3                วันที่ 25-29 มกราคม 2564  202104                1      0.0
# 4              วันที่ 1-5 กุมภาพันธ์ 2564  202105                1      1.0
# 5             วันที่ 8-11 กุมภาพันธ์ 2564  202106                1      1.0
# 6            วันที่ 15-19 กุมภาพันธ์ 2564  202107                1      1.0
# 7            วันที่ 22-25 กุมภาพันธ์ 2564  202108                1      1.0
# 8                  วันที่ 1-5 มีนาคม 2564  202109                1      1.0
# 9                 วันที่ 8-12 มีนาคม 2564  202110                0      1.0
# 10               วันที่ 15-19 มีนาคม 2564  202111                1      1.0
# 11               วันที่ 22-26 มีนาคม 2564  202112                0      1.0
# 12       วันที่ 29 มีนาคม - 2 เมษายน 2564  202113                1      1.0
# 13                 วันที่ 5-9 เมษายน 2564  202114                0      1.0
# 14               วันที่ 12-16 เมษายน 2564  202115                1      1.0
# 15               วันที่ 19-23 เมษายน 2564  202116                1      1.0
# 16               วันที่ 26-30 เมษายน 2564  202117                0      0.0
# 17                วันที่ 3-7 พฤษภาคม 2564  202118                1      0.0
# 18              วันที่ 10-14 พฤษภาคม 2564  202119                0      0.0
# 19              วันที่ 17-21 พฤษภาคม 2564  202120                0      0.0
# 20              วันที่ 24-28 พฤษภาคม 2564  202121                1      0.0
# 21    วันที่ 31 พฤษภาคม - 4 มิถุนายน 2564  202122                0      1.0
# 22              วันที่ 7-11 มิถุนายน 2564  202123                0      0.0
# 23             วันที่ 14-18 มิถุนายน 2564  202124                0      0.0
# 24             วันที่ 21-25 มิถุนายน 2564  202125                1      0.0
# 25    วันที่ 28 มิถุนายน - 2 กรกฎาคม 2564  202126                0      0.0
# 26                วันที่ 5-9 กรกฎาคม 2564  202127                1      1.0
# 27              วันที่ 12-16 กรกฎาคม 2564  202128                0      1.0
# 28              วันที่ 19-23 กรกฎาคม 2564  202129                0      0.0
# 29              วันที่ 26-30 กรกฎาคม 2564  202130                0      0.0
# 30                วันที่ 2-6 สิงหาคม 2564  202131                1      0.0
# 31               วันที่ 9-13 สิงหาคม 2564  202132                0      1.0
# 32              วันที่ 23-27 สิงหาคม 2564  202134                0      1.0
# 33     วันที่ 30 สิงหาคม - 3 กันยายน 2564  202135                0      0.0
# 34               วันที่ 6-10 กันยายน 2564  202136                1      1.0
# 35              วันที่ 13-17 กันยายน 2564  202137                0      1.0
# 36              วันที่ 20-24 กันยายน 2564  202138                0      1.0
# 37      วันที่ 27 กันยายน - 1 ตุลาคม 2564  202139                0      1.0
# 38               วันที่ 4 - 8 ตุลาคม 2564  202140                0      1.0
# 39               วันที่ 11-15 ตุลาคม 2564  202141                1      0.0
# 40               วันที่ 18-21 ตุลาคม 2564  202142                1      1.0
# 41               วันที่ 25-29 ตุลาคม 2564  202143                0      1.0
# 42              วันที่ 1-5 พฤศจิกายน 2564  202144                0      1.0
# 43             วันที่ 8-12 พฤศจิกายน 2564  202145                1      1.0
# 44            วันที่ 15-19 พฤศจิกายน 2564  202146                1      1.0
# 45            วันที่ 22-26 พฤศจิกายน 2564  202147                0      1.0
# 46   วันที่ 29 พฤศจิกายน - 3 ธันวาคม 2564  202148                1      0.0
# 47               วันที่ 6-10 ธันวาคม 2564  202149                1      1.0
# 48              วันที่ 13-17 ธันวาคม 2564  202150                1      1.0
# 49              วันที่ 20-24 ธันวาคม 2564  202151                1      1.0
# 50              วันที่ 27-29 ธันวาคม 2564  202152                1      1.0
# 51                 วันที่ 3-7 มกราคม 2565  202201                0      1.0
# 52               วันที่ 10-14 มกราคม 2565  202202                1      0.0
# 53               วันที่ 17-21 มกราคม 2565  202203                1      1.0
# 54               วันที่ 24-28 มกราคม 2565  202204                1      1.0
# 55   วันที่ 31 มกราคม - 4 กุมภาพันธ์ 2565  202205                1      1.0
#
#     week_close_price    %return
# 0            1374.75       None
# 1            1416.75       None
# 2            1311.75  -4.582651
# 3            1370.00       None
# 4            1366.75  -4.024145
# 5            1372.00       None
# 6            1377.25       None
# 7            1405.25       None
# 8            1430.00       None
# 9            1413.25       None
# 10           1416.25       None
# 11           1400.50       None
# 12           1402.00       None
# 13           1403.00       None
# 14           1433.25       None
# 15           1539.75       None
# 16           1571.00  14.944211
# 17           1589.75       None
# 18           1586.25       None
# 19           1526.25       None
# 20           1530.50       None
# 21           1583.75  -0.805051
# 22           1508.50  -4.751381
# 23           1396.00       None
# 24           1329.75       None
# 25           1433.25       None
# 26           1379.25   9.371035
# 27           1454.75       None
# 28           1401.00   1.576944
# 29           1414.75       None
# 30           1344.25       None
# 31           1373.00    2.03933
# 32           1359.25       None
# 33           1292.00   -5.89949
# 34           1286.50   0.427517
# 35           1284.00       None
# 36           1285.00       None
# 37           1246.50       None
# 38           1243.00       None
# 39           1217.75  -5.343956
# 40           1220.50  -0.225317
# 41           1235.75       None
# 42           1205.50       None
# 43           1244.25       None
# 44           1263.25       None
# 45           1252.75       None
# 46           1267.25   3.830397
# 47           1267.75   -0.03944
# 48           1285.25       None
# 49           1332.00       None
# 50           1328.75       None
# 51           1410.25       None
# 52           1369.75    8.04575
# 53           1414.25  -3.146544
# 54           1470.00       None
# 55           1553.50  10.096208

# %%
p_return['%return_after_comm'] = p_return['%return'].apply(lambda x : None if x is None else x-0.5)
p_return
# Out:
#                                      week   dates  price_next_week  y_hat_w  \
# 0                วันที่ 4 - 8 มกราคม 2564  202101                1      1.0
# 1                วันที่ 11-15 มกราคม 2564  202102                0      1.0
# 2                วันที่ 18-22 มกราคม 2564  202103                0      0.0
# 3                วันที่ 25-29 มกราคม 2564  202104                1      0.0
# 4              วันที่ 1-5 กุมภาพันธ์ 2564  202105                1      1.0
# 5             วันที่ 8-11 กุมภาพันธ์ 2564  202106                1      1.0
# 6            วันที่ 15-19 กุมภาพันธ์ 2564  202107                1      1.0
# 7            วันที่ 22-25 กุมภาพันธ์ 2564  202108                1      1.0
# 8                  วันที่ 1-5 มีนาคม 2564  202109                1      1.0
# 9                 วันที่ 8-12 มีนาคม 2564  202110                0      1.0
# 10               วันที่ 15-19 มีนาคม 2564  202111                1      1.0
# 11               วันที่ 22-26 มีนาคม 2564  202112                0      1.0
# 12       วันที่ 29 มีนาคม - 2 เมษายน 2564  202113                1      1.0
# 13                 วันที่ 5-9 เมษายน 2564  202114                0      1.0
# 14               วันที่ 12-16 เมษายน 2564  202115                1      1.0
# 15               วันที่ 19-23 เมษายน 2564  202116                1      1.0
# 16               วันที่ 26-30 เมษายน 2564  202117                0      0.0
# 17                วันที่ 3-7 พฤษภาคม 2564  202118                1      0.0
# 18              วันที่ 10-14 พฤษภาคม 2564  202119                0      0.0
# 19              วันที่ 17-21 พฤษภาคม 2564  202120                0      0.0
# 20              วันที่ 24-28 พฤษภาคม 2564  202121                1      0.0
# 21    วันที่ 31 พฤษภาคม - 4 มิถุนายน 2564  202122                0      1.0
# 22              วันที่ 7-11 มิถุนายน 2564  202123                0      0.0
# 23             วันที่ 14-18 มิถุนายน 2564  202124                0      0.0
# 24             วันที่ 21-25 มิถุนายน 2564  202125                1      0.0
# 25    วันที่ 28 มิถุนายน - 2 กรกฎาคม 2564  202126                0      0.0
# 26                วันที่ 5-9 กรกฎาคม 2564  202127                1      1.0
# 27              วันที่ 12-16 กรกฎาคม 2564  202128                0      1.0
# 28              วันที่ 19-23 กรกฎาคม 2564  202129                0      0.0
# 29              วันที่ 26-30 กรกฎาคม 2564  202130                0      0.0
# 30                วันที่ 2-6 สิงหาคม 2564  202131                1      0.0
# 31               วันที่ 9-13 สิงหาคม 2564  202132                0      1.0
# 32              วันที่ 23-27 สิงหาคม 2564  202134                0      1.0
# 33     วันที่ 30 สิงหาคม - 3 กันยายน 2564  202135                0      0.0
# 34               วันที่ 6-10 กันยายน 2564  202136                1      1.0
# 35              วันที่ 13-17 กันยายน 2564  202137                0      1.0
# 36              วันที่ 20-24 กันยายน 2564  202138                0      1.0
# 37      วันที่ 27 กันยายน - 1 ตุลาคม 2564  202139                0      1.0
# 38               วันที่ 4 - 8 ตุลาคม 2564  202140                0      1.0
# 39               วันที่ 11-15 ตุลาคม 2564  202141                1      0.0
# 40               วันที่ 18-21 ตุลาคม 2564  202142                1      1.0
# 41               วันที่ 25-29 ตุลาคม 2564  202143                0      1.0
# 42              วันที่ 1-5 พฤศจิกายน 2564  202144                0      1.0
# 43             วันที่ 8-12 พฤศจิกายน 2564  202145                1      1.0
# 44            วันที่ 15-19 พฤศจิกายน 2564  202146                1      1.0
# 45            วันที่ 22-26 พฤศจิกายน 2564  202147                0      1.0
# 46   วันที่ 29 พฤศจิกายน - 3 ธันวาคม 2564  202148                1      0.0
# 47               วันที่ 6-10 ธันวาคม 2564  202149                1      1.0
# 48              วันที่ 13-17 ธันวาคม 2564  202150                1      1.0
# 49              วันที่ 20-24 ธันวาคม 2564  202151                1      1.0
# 50              วันที่ 27-29 ธันวาคม 2564  202152                1      1.0
# 51                 วันที่ 3-7 มกราคม 2565  202201                0      1.0
# 52               วันที่ 10-14 มกราคม 2565  202202                1      0.0
# 53               วันที่ 17-21 มกราคม 2565  202203                1      1.0
# 54               วันที่ 24-28 มกราคม 2565  202204                1      1.0
# 55   วันที่ 31 มกราคม - 4 กุมภาพันธ์ 2565  202205                1      1.0
#
#     week_close_price    %return  %return_after_comm
# 0            1374.75       None                 NaN
# 1            1416.75       None                 NaN
# 2            1311.75  -4.582651           -5.082651
# 3            1370.00       None                 NaN
# 4            1366.75  -4.024145           -4.524145
# 5            1372.00       None                 NaN
# 6            1377.25       None                 NaN
# 7            1405.25       None                 NaN
# 8            1430.00       None                 NaN
# 9            1413.25       None                 NaN
# 10           1416.25       None                 NaN
# 11           1400.50       None                 NaN
# 12           1402.00       None                 NaN
# 13           1403.00       None                 NaN
# 14           1433.25       None                 NaN
# 15           1539.75       None                 NaN
# 16           1571.00  14.944211           14.444211
# 17           1589.75       None                 NaN
# 18           1586.25       None                 NaN
# 19           1526.25       None                 NaN
# 20           1530.50       None                 NaN
# 21           1583.75  -0.805051           -1.305051
# 22           1508.50  -4.751381           -5.251381
# 23           1396.00       None                 NaN
# 24           1329.75       None                 NaN
# 25           1433.25       None                 NaN
# 26           1379.25   9.371035            8.871035
# 27           1454.75       None                 NaN
# 28           1401.00   1.576944            1.076944
# 29           1414.75       None                 NaN
# 30           1344.25       None                 NaN
# 31           1373.00    2.03933            1.539330
# 32           1359.25       None                 NaN
# 33           1292.00   -5.89949           -6.399490
# 34           1286.50   0.427517           -0.072483
# 35           1284.00       None                 NaN
# 36           1285.00       None                 NaN
# 37           1246.50       None                 NaN
# 38           1243.00       None                 NaN
# 39           1217.75  -5.343956           -5.843956
# 40           1220.50  -0.225317           -0.725317
# 41           1235.75       None                 NaN
# 42           1205.50       None                 NaN
# 43           1244.25       None                 NaN
# 44           1263.25       None                 NaN
# 45           1252.75       None                 NaN
# 46           1267.25   3.830397            3.330397
# 47           1267.75   -0.03944           -0.539440
# 48           1285.25       None                 NaN
# 49           1332.00       None                 NaN
# 50           1328.75       None                 NaN
# 51           1410.25       None                 NaN
# 52           1369.75    8.04575            7.545750
# 53           1414.25  -3.146544           -3.646544
# 54           1470.00       None                 NaN
# 55           1553.50  10.096208            9.596208

# %%
np.mean(p_return['%return_after_comm'])/np.std(p_return['%return_after_comm'], ddof=1)
# Out:
# 0.12440275428864375

# %%
p_return['%return_after_comm'].sum()
# Out:
# 13.013415139027897

# %%
all_years = [2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022]
split_index = 6

summary = {
    'year' : [],
    '%return_after_comm' : [],
    'profit' : [],
    'loss' : [],
    'MDD' : []
}

for year in all_years:
  current_year_data = get_data_from_years(p_return, [year])
  summary['year'].append(year)
  summary['%return_after_comm'].append(round(current_year_data['%return_after_comm'].sum(), 2))
  summary['MDD'].append(abs(round(current_year_data['%return'].min(), 2)))
  summary['profit'].append(len(current_year_data[current_year_data['%return_after_comm'] >= 0]))
  summary['loss'].append(len(current_year_data[current_year_data['%return_after_comm'] < 0]))

# %%
summary = pd.DataFrame(summary)
summary
# Out:
#    year  %return_after_comm  profit  loss   MDD
# 0  2015                0.00       0     0   NaN
# 1  2016                0.00       0     0   NaN
# 2  2017                0.00       0     0   NaN
# 3  2018                0.00       0     0   NaN
# 4  2019                0.00       0     0   NaN
# 5  2020                0.00       0     0   NaN
# 6  2021               -0.48       5     9  5.90
# 7  2022               13.50       2     1  3.15

# %%
for idx in summary['profit'].index, summary['loss'].index:

  A = summary['profit'][idx]
  B = summary['loss'][idx]

  summary.loc[idx, 'accuracy'] = round((A / ( A + B ))*100, 2)

summary
# Out:
#    year  %return_after_comm  profit  loss   MDD  accuracy
# 0  2015                0.00       0     0   NaN       NaN
# 1  2016                0.00       0     0   NaN       NaN
# 2  2017                0.00       0     0   NaN       NaN
# 3  2018                0.00       0     0   NaN       NaN
# 4  2019                0.00       0     0   NaN       NaN
# 5  2020                0.00       0     0   NaN       NaN
# 6  2021               -0.48       5     9  5.90     35.71
# 7  2022               13.50       2     1  3.15     66.67

# %%
(summary['profit'].sum()/(summary['profit'].sum()+summary['loss'].sum()))*100
# Out:
# 41.17647058823529
